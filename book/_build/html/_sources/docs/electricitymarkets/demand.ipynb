# %% [markdown]
# # Forecasting Regional Electricity Demand

# %% [markdown]
# {badge}`R,badge-primary` {badge}`forecasting,badge-secondary` {badge}`energy market,badge-warning`

# %% [markdown]
# This post explores time series forecasting models for the 5-min regional electricity demand data from the Electricity Market of the Philippines.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Libraries

# %%
library(data.table)
library(forecast)
library(ggplot2)
library(ggforce)
library(rpart)
library(lubridate)

# %% [markdown]
# ### Paths

# %%
filename = "/Volumes/data/projects/django-mms/data/demand_daily/luzon-hourly-demand.csv"

# %%
dt = fread(filename,sep=",")

# %%
head(dt)
# Out:
#   TIME_INTERVAL       MKT_REQT LOAD_BID LOAD_CURTAILED LOSSES   GENERATION
# 1 2021-06-26 00:00:00 7763.500 320.0000 0              138.0200 8147.067
# 2 2021-06-26 01:00:00 7887.279 466.6667 0              147.4142 8401.715
# 3 2021-06-26 02:00:00 7527.432 480.0000 0              139.3717 7996.198
# 4 2021-06-26 03:00:00 7326.856 480.0000 0              131.8258 7722.851
# 5 2021-06-26 04:00:00 7104.273 480.0000 0              121.6275 7492.467
# 6 2021-06-26 05:00:00 6941.924 480.0000 0              115.4933 7348.954
#   MKT_IMPORT MKT_EXPORT
# 1  74.45909  0
# 2  99.62167  0
# 3 150.60667  0
# 4 215.86000  0
# 5 213.44250  0
# 6 188.46833  0

# %%
n_date <- unique(dt[, TIME_INTERVAL])
length(n_date)
# Out:
# [1] 1201

# %%
dt_train <- dt[TIME_INTERVAL %in% n_date[1:1000]]
dt_test <- dt[TIME_INTERVAL %in% n_date[1001:1201]]
head(dt_test)
# Out:
#   TIME_INTERVAL       MKT_REQT LOAD_BID LOAD_CURTAILED LOSSES   GENERATION
# 1 2021-08-06 16:00:00 9159.344 0        0              134.9275 9299.358
# 2 2021-08-06 17:00:00 8681.993 0        0              120.0200 8827.621
# 3 2021-08-06 18:00:00 8675.513 0        0              124.0275 8859.455
# 4 2021-08-06 19:00:00 8907.350 0        0              131.9883 9071.607
# 5 2021-08-06 20:00:00 8963.976 0        0              136.3025 9121.383
# 6 2021-08-06 21:00:00 9022.061 0        0              142.3233 9158.010
#   MKT_IMPORT MKT_EXPORT
# 1 0.00000000  5.123333
# 2 0.02166667 25.593333
# 3 0.00000000 59.943333
# 4 0.00000000 32.282500
# 5 0.00000000 21.055833
# 6 8.20333333  1.846667

# %% [markdown]
# ## Decomposition using STL

# %%
plot(ts(dt_train$MKT_REQT, freq = 24))
# Out:
# plot without title

# %%
data_ts <- ts(dt_train$MKT_REQT, freq = 24*7)

decomp_ts <- stl(data_ts, s.window = "periodic", robust = TRUE)$time.series

# %%
autoplot(stl(data_ts, s.window = "periodic", robust = TRUE))
# Out:
# plot without title

# %% [markdown]
# ### Exponential Models

# %%
fit = HoltWinters(data_ts, beta=FALSE, gamma=FALSE)

# %%
accuracy(fit)
# Out:
# Error in accuracy.default(fit): First argument should be a forecast object or a time series.
# Traceback:
#
# 1. accuracy(fit)
# 2. accuracy.default(fit)
# 3. stop("First argument should be a forecast object or a time series.")

# %%
fit
# Out:
# Holt-Winters exponential smoothing without trend and without seasonal component.
#
# Call:
# HoltWinters(x = data_ts, beta = FALSE, gamma = FALSE)
#
# Smoothing parameters:
#  alpha: 0.9999262
#  beta : FALSE
#  gamma: FALSE
#
# Coefficients:
#       [,1]
# a 9434.748

# %%
forecast(fit, 3)
plot(forecast(fit, 100))
# Out:
#          Point Forecast    Lo 80     Hi 80    Lo 95    Hi 95
# 6.952381       9434.748 9045.771  9823.726 8839.859 10029.64
# 6.958333       9434.748 8884.672  9984.825 8593.479 10276.02
# 6.964286       9434.748 8761.053 10108.444 8404.420 10465.08
# Plot with title “Forecasts from HoltWinters”

# %% [markdown]
# ### Arima

# %%
fit = arima(data_ts, order=c(p, d, q))

#accuracy(fit)

forecast(fit, 5)
plot(forecast(fit, 5))
# Out:
# Error in arima(data_ts, order = c(p, d, q)): object 'p' not found
# Traceback:
#
# 1. arima(data_ts, order = c(p, d, q))

# %%
fit <- ets(data_ts)


plot(forecast(fit, 50))
# Out:
# Warning message in ets(data_ts):
# “I can't handle data with frequency greater than 24. Seasonality will be ignored. Try stlf() if you need seasonal forecasts.”
# Plot with title “Forecasts from ETS(M,Ad,N)”

# %%
# Automated forecasting using an ARIMA model
fit <- auto.arima(data_ts)
plot(forecast(fit, 5))
# Out:
# Plot with title “Forecasts from ARIMA(1,1,5)(0,1,0)[168]”

# %%
plot(forecast(fit, 50))
# Out:
# Plot with title “Forecasts from ARIMA(1,1,5)(0,1,0)[168]”

# %%
# remove last date
dt  <- dt[-nrow(dt),]

# %%
dt$TIME_INTERVAL  <-  ymd_hms(dt$TIME_INTERVAL)

# %%
dt$HOUR  <- hour(dt$TIME_INTERVAL) + 1

# %%
dt$WEEK_NUM  <-  as.numeric(strftime(as.Date(dt$TIME_INTERVAL, "%Y-%m-%d"), "%u"))
# Out:
# Warning message in as.POSIXlt.POSIXct(x, tz = tz):
# “unknown timezone '%Y-%m-%d'”

# %%
period  <- 24
N <- nrow(dt) # number of observations in the train set
window <- N / period # number of days in the train set
matrix_data <- data.table(Load = dt[, MKT_REQT],
                         Daily = rep(1:period, window),
                         Weekly = dt[, WEEK_NUM])

# %%
head(matrix_data)
# Out:
#      Load     Daily Weekly
# 1    7763.500  1    6
# 2    7887.279  2    6
# 3    7527.432  3    6
# 4    7326.856  4    6
# 5    7104.273  5    6
# 6    6941.924  6    6
# 7    7008.685  7    6
# 8    7254.535  8    6
# 9    7877.656  9    6
# 10   8612.843 10    6
# 11   8951.603 11    6
# 12   9140.541 12    6
# 13   8946.171 13    6
# 14   9153.241 14    6
# 15   9186.632 15    6
# 16   8894.834 16    6
# 17   8689.929 17    6
# 18   8477.302 18    6
# 19   8765.159 19    6
# 20   8962.177 20    6
# 21   9069.043 21    6
# 22   9126.257 22    6
# 23   8931.969 23    6
# 24   8609.438 24    6
# 25   8238.253  1    7
# 26   7989.458  2    7
# 27   7720.821  3    7
# 28   7454.262  4    7
# 29   7252.114  5    7
# 30   6998.883  6    7
# ⋮    ⋮        ⋮     ⋮
# 1171 8604.976 19    5
# 1172 8685.551 20    5
# 1173 8747.549 21    5
# 1174 8782.125 22    5
# 1175 8556.896 23    5
# 1176 8254.362 24    5
# 1177 7979.416  1    6
# 1178 7712.682  2    6
# 1179 7479.121  3    6
# 1180 7228.326  4    6
# 1181 7125.363  5    6
# 1182 7029.163  6    6
# 1183 6925.574  7    6
# 1184 7234.852  8    6
# 1185 7670.774  9    6
# 1186 8107.201 10    6
# 1187 8568.875 11    6
# 1188 8726.774 12    6
# 1189 8657.291 13    6
# 1190 8831.841 14    6
# 1191 8600.313 15    6
# 1192 8294.451 16    6
# 1193 8055.973 17    6
# 1194 7867.397 18    6
# 1195 8218.355 19    6
# 1196 8460.562 20    6
# 1197 8400.203 21    6
# 1198 8444.838 22    6
# 1199 8189.015 23    6
# 1200 7973.204 24    6

# %%
n_date <- unique(dt[, TIME_INTERVAL])

# %%
data_train <- dt[TIME_INTERVAL %in% n_date[1:1176]]
data_test <- dt[TIME_INTERVAL %in% n_date[1177:1200]]

# %%
data_ts <- ts(data_train$MKT_REQT, freq = period * 7)
decomp_ts <- stl(data_ts, s.window = "periodic", robust = TRUE)$time.series
 
decomp_stl <- data.table(MKT_REQT = c(data_train$MKT_REQT, as.numeric(decomp_ts)),
                         TIME_INTERVAL = rep(data_train[,TIME_INTERVAL], ncol(decomp_ts)+1),
                         Type = factor(rep(c("original data", colnames(decomp_ts)),
                                       each = nrow(decomp_ts)),
                                       levels = c("original data", colnames(decomp_ts))))
 
ggplot(decomp_stl, aes(x = TIME_INTERVAL, y = MKT_REQT)) +
  geom_line() + 
  facet_grid(Type ~ ., scales = "free_y", switch = "y") +
  labs(x = "Date", y = NULL,
       title = "Time Series Decomposition by STL")
# Out:
# plot without title

# %% [markdown]
# ## Constructing features to model

# %%
# multiseasonal object
data_msts <- msts(data_train$MKT_REQT, seasonal.periods = c(period, period*7))

# %%
K <- 2
fuur <- fourier(data_msts, K = c(K, K))

# %%
# 2 pairs of sine and cosine values for daily and weekly season
head(fuur)
# Out:
#      S1-24     C1-24     S2-24     C2-24      S1-168     C1-168    S2-168
# [1,] 0.2588190 0.9659258 0.5000000  0.8660254 0.03739119 0.9993007 0.07473009
# [2,] 0.5000000 0.8660254 0.8660254  0.5000000 0.07473009 0.9972038 0.14904227
# [3,] 0.7071068 0.7071068 1.0000000  0.0000000 0.11196448 0.9937122 0.22252093
# [4,] 0.8660254 0.5000000 0.8660254 -0.5000000 0.14904227 0.9888308 0.29475517
# [5,] 0.9659258 0.2588190 0.5000000 -0.8660254 0.18591161 0.9825665 0.36534102
# [6,] 1.0000000 0.0000000 0.0000000 -1.0000000 0.22252093 0.9749279 0.43388374
#      C2-168
# [1,] 0.9972038
# [2,] 0.9888308
# [3,] 0.9749279
# [4,] 0.9555728
# [5,] 0.9308737
# [6,] 0.9009689

# %%
# forecasting the trend from STL
trend_part <- ts(decomp_ts[,2])
trend_fit <- auto.arima(trend_part)
trend_for <- forecast(trend_fit, period)$mean

# %%
trend_data <- data.table(MKT_REQT = c(decomp_ts[,2], trend_for),
                         TIME_INTERVAL = c(data_train$TIME_INTERVAL, data_test$TIME_INTERVAL),
                         Type = c(rep("Real", nrow(data_train)), rep("Forecast",
                                                                     nrow(data_test))))
 
ggplot(trend_data, aes(TIME_INTERVAL, MKT_REQT, color = Type)) +
  geom_line(size = 1.2) +
  labs(title = paste(trend_fit))
# Out:
# plot without title

# %%
# Add lag feature
N <- nrow(data_train)
window <- (N / period) - 1 # number of days in train set minus lag
 
new_MKT_REQT <- rowSums(decomp_ts[, c(1,3)]) # detrended load
lag_seas <- decomp_ts[1:(period*window), 1] # seasonal part of time series as lag feature
 
matrix_train <- data.table(MKT_REQT = tail(new_MKT_REQT, window*period),
                           fuur[(period + 1):N,],
                           Lag = lag_seas)

# %%
head(matrix_train)
# Out:
#   MKT_REQT   S1-24     C1-24     S2-24     C2-24      S1-168    C1-168
# 1  -470.1428 0.2588190 0.9659258 0.5000000  0.8660254 0.8045978 0.5938202
# 2  -719.2230 0.5000000 0.8660254 0.8660254  0.5000000 0.8262388 0.5633201
# 3  -988.1449 0.7071068 0.7071068 1.0000000  0.0000000 0.8467242 0.5320321
# 4 -1254.7294 0.8660254 0.5000000 0.8660254 -0.5000000 0.8660254 0.5000000
# 5 -1456.9022 0.9659258 0.2588190 0.5000000 -0.8660254 0.8841154 0.4672686
# 6 -1710.1593 1.0000000 0.0000000 0.0000000 -1.0000000 0.9009689 0.4338837
#   S2-168    C2-168     Lag
# 1 0.9555728 -0.2947552  -346.6269
# 2 0.9308737 -0.3653410  -638.9261
# 3 0.9009689 -0.4338837  -904.8643
# 4 0.8660254 -0.5000000 -1109.9838
# 5 0.8262388 -0.5633201 -1237.1313
# 6 0.7818315 -0.6234898 -1341.9789

# %%
# Accuracy MAPE - Mean Absolute Percentage Error
mape <- function(real, pred){
  return(100 * mean(abs((real - pred)/real)))
}

# %% [markdown]
# ## RPART

# %%
tree_1 <- rpart(MKT_REQT ~ ., data = matrix_train)

# %%
tree_1$variable.importance
# Out:
#       Lag     S1-24    S1-168     C1-24     S2-24     C2-24    C2-168    S2-168
# 551671375 530809911 198491989 179980249  84011521  63647555  52135692  36623745
#    C1-168
#  31529369

# %%
paste("Number of splits: ", tree_1$cptable[dim(tree_1$cptable)[1], "nsplit"])
# Out:
# [1] "Number of splits:  9"

# %%
install.packages("rpart.plot")
library(rpart.plot)
# Out:
# The downloaded binary packages are in
# 	/var/folders/47/k_hjs6l952v72vlq22ljz29w0000gn/T//RtmptCLiw5/downloaded_packages

# %%
rpart.plot(tree_1, digits = 2, 
           box.palette = viridis::viridis(10, option = "D", begin = 0.85, end = 0), 
           shadow.col = "grey65", col = "grey99")
# Out:
# plot without title

# %%
datas <- data.table(MKT_REQT = c(matrix_train$MKT_REQT,
                             predict(tree_1)),
                    TIME_INTERVAL = rep(1:length(matrix_train$MKT_REQT), 2),
                    Type = rep(c("Real", "RPART"), each = length(matrix_train$MKT_REQT)))
 
ggplot(datas, aes(TIME_INTERVAL, MKT_REQT, color = Type)) +
  geom_line(size = 0.8, alpha = 0.75) +
  labs(y = "Detrended load", title = "Fitted values from RPART tree")
# Out:
# plot without title

# %%
mape(matrix_train$MKT_REQT, predict(tree_1))
# Out:
# [1] 559.0849

# %% [markdown]
# ## Improvment

# %%
tree_2 <- rpart(MKT_REQT ~ ., data = matrix_train,
                control = rpart.control(minsplit = 2,
                                        maxdepth = 30,
                                        cp = 0.000001))

# %%
plot(tree_2, compress = TRUE)
# Out:
# plot without title

# %%
tree_2$cptable[dim(tree_2$cptable)[1], "nsplit"] # Number of splits
# Out:
# [1] 465

# %%
datas <- data.table(MKT_REQT = c(matrix_train$MKT_REQT,
                             predict(tree_2)),
                    TIME_INTERVAL = rep(1:length(matrix_train$MKT_REQT), 2),
                    Type = rep(c("Real", "RPART"), each = length(matrix_train$MKT_REQT)))
 
ggplot(datas, aes(TIME_INTERVAL, MKT_REQT, color = Type)) +
  geom_line(size = 0.8, alpha = 0.75) +
  labs(y = "Detrended load", title = "Fitted values from RPART")
# Out:
# plot without title

# %%
mape(matrix_train$MKT_REQT, predict(tree_2))
# Out:
# [1] 68.93864

# %% [markdown]
# ## Add trend forecast

# %%
test_lag <- decomp_ts[((period*window)+1):N, 1]
fuur_test <- fourier(data_msts, K = c(K, K), h = period)
 
matrix_test <- data.table(fuur_test,
                          Lag = test_lag)

# %%
for_rpart <- predict(tree_2, matrix_test) + trend_for

# %%
data_for <- data.table(MKT_REQT = c(data_train$MKT_REQT, data_test$MKT_REQT, for_rpart),
                       TIME_INTERVAL = c(data_train$TIME_INTERVAL, rep(data_test$TIME_INTERVAL, 2)),
                       Type = c(rep("Train data", nrow(data_train)),
                                rep("Test data", nrow(data_test)),
                                rep("Forecast", nrow(data_test))))
 
ggplot(data_for, aes(TIME_INTERVAL, MKT_REQT, color = Type)) +
  geom_line(size = 0.8, alpha = 0.75) +
  facet_zoom(x = TIME_INTERVAL %in% data_test$TIME_INTERVAL, zoom.size = 1.2) +
  labs(title = "Forecast from RPART")
# Out:
# plot without title
